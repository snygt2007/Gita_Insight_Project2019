# %%
import keras
import os
import typing
import re
import matplotlib.pyplot as plt
import pandas as pd
import glob
import os
import math
import numpy as np
import cv2
import json
from pathlib import Path

# %%
#import all libraries
from PIL import Image, ImageOps,ImageFilter
#import cv2
import time
import argparse
from scipy import ndimage
from scipy import misc
# %matplotlib inline
import readline
readline.parse_and_bind("tab: complete")
from scipy import ndimage
from multiprocessing.pool import ThreadPool

from urllib.request import Request, urlopen, HTTPError
import ssl

# %%
import os
import numpy as np
import argparse
from keras.models import Model
from PIL import Image, ImageOps,ImageFilter
import matplotlib.image as mpimg
import csv
from numpy import linalg
from pandas import HDFStore

# %%
import os

dir_litw_resized=Path("c:/Users/Sanyogita/Documents/Insight/projects/Trademark_RADAR/large_data/resized_images_details_v9")
dir_litw =Path("c:/Users/Sanyogita/Documents/Insight/projects/Trademark_RADAR/large_data/Raw_data")
dir_litw_super_cleaned=Path("c:/Users/Sanyogita/Documents/Insight/projects/Trademark_RADAR/Git_version/data/filtered_supervised_image_v9")

# %%
def Get_folder_name_labels(dir_path):

    df_logos_folder = pd.DataFrame(columns=['true_logo','folder_name','folder_img_count'])
    mn = 0
    folders = ([name for name in sorted(os.listdir(dir_litw), key=str.casefold)]) # get all directories 
    num_folders =1

    for company_name in folders:
        contents = os.listdir(os.path.join(dir_path,company_name)) # get list of contents
        if len(contents) <= mn: # if greater than the limit, print folder and number of contents
            continue
        row = pd.Series({'true_logo' :num_folders,
                         'folder_name' :company_name,
                        'folder_img_count': len(contents),
                        'folder_path': os.path.join(dir_path,company_name),})
        print(os.path.join(dir_path,company_name))
        print("length:",str(len(contents)))
        num_folders = num_folders+1
        df_logos_folder = df_logos_folder.append(row,ignore_index=True)   
        
    
    return df_logos_folder

# %%
df_logos_folder_label=Get_folder_name_labels(dir_litw)
print("total folder", str(df_logos_folder_label.shape))
# Out:
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\1fcköln
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\24fitness
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\7eleven
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\a1
# length: 17
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\absolutvodka
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\abus
# length: 76
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\accenture
# length: 66
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\accenture-symbol
# length: 4
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\acer
# length: 7
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\acm
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\adac
# length: 3
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\adams
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\adidas-text
# length: 28
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\adidas1
# length: 117
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\adidas3
# length: 31
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\affligem
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\africola
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aftereight
# length: 3
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\ahojbrause
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aircanada
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\airhawk
# length: 20
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\airweave
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\alba
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aldi
# length: 245
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\alfaromeo
# length: 4
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\allett
# length: 21
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\allianz
# length: 148
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\allianz-symbol
# length: 150
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\alpengold
# length: 3
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aluratek-symbol
# length: 19
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aluratek-text
# length: 18
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amazon
# length: 50
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amazon-symbol
# length: 4
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amcrest
# length: 41
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amcrest-symbol
# length: 39
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\america
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\americanexpress
# length: 49
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amg
# length: 4
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amlactin
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amsa
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amstel
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\amv
# length: 3
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\android
# length: 3
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\angrybirds
# length: 11
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\apc
# length: 27
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\apecase-symbol
# length: 16
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\apecase-text
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\apollo
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\apple
# length: 21
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\applebee
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\applebees
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aquapac
# length: 20
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aquapac-symbol
# length: 4
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aral
# length: 163
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\armitron
# length: 54
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\asda
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\aspirin
# length: 47
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\asus
# length: 11
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\at&t
# length: 14
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\athalon
# length: 7
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\athalon-symbol
# length: 9
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\ati
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\audi-symbol
# length: 229
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\audi-text
# length: 121
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\avaya
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\axa
# length: 33
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\axe
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\azeca
# length: 11
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\baffodoro
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\bagelbites
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\balenciaga
# length: 1
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\zeppelin
# length: 2
# c:\Users\Sanyogita\Documents\Insight\projects\Trademark_RADAR\large_data\Raw_data\zippo
# length: 1
# total folder (776, 4)

# %%
#Image processing for resizing images
def fix_aspect_ratio(img,expected_dimension):
    original_max_dim = max(float(img.size[0]),float(img.size[1]))
    original_min_dim = min(float(img.size[0]),float(img.size[1]))
    wpercent = (expected_dimension/float(original_max_dim))
    hsize = int((original_min_dim*float(wpercent)))
    new_im = img.resize((expected_dimension,hsize), Image.ANTIALIAS)
    return new_im

# %%
# Make square images
def make_square(img, min_size=120, fill_color=(0, 0, 0, 0)):
    x, y = img.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(img, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

# %%
# Sharpen the edges
from pylab import *
def sharpen_filter(img):
    sharp_im = img.filter(ImageFilter.SHARPEN)
    return sharp_im

# %%
def verify_images_df(glob_path_complete, folder_name,dir_litw_resized, size_threshold,folder_label,expected_dimension):
    try:
        
         # in each folder, find image file and resize-scale them without distortion

        glob_path_complete_path =Path(os.path.join(glob_path_complete,folder_name))
    
        for filename_logo in glob_path_complete_path.glob('**/*.jpg'):
            img = Image.open(filename_logo) # open the image file
            img.verify() # verify that it is, in fact an image
    except (IOError, SyntaxError) as e:
        print('Bad file:', filename_logo) # print out the names of corrupt files

# %%
import scipy.signal
def calculate_MSCN_val(img):
    C=3.0/255.0
    blurred_img=cv2.GaussianBlur(img, (7, 7), 1.166)
    blurred_sq = blurred_img * blurred_img 
    sigma = cv2.GaussianBlur(img * img, (7, 7), 1.166) 
    sigma = (sigma - blurred_sq) ** 0.5
    sigma = sigma + C
    MCSN_value = (img - blurred_img)/sigma
    return MCSN_value

# %%
# Load dataset of logos in a dataframe
def resize_images_df(folder_path_global, company_name,dir_litw_resized, expected_dimension,size_threshold, folder_logo_num):
    df_logos_pickle = pd.DataFrame(columns=['true_logo','logo_img_name','original_image_name','company_brand','folder_path','mean_mean_val','mean_std_val','mscn_val'])
    
     # in each folder, find image file and resize-scale them without distortion
    index_image= 1;
    #print(glob_path_complete) 
    glob_path_complete_path_inter=os.path.join(folder_path_global,company_name)
    glob_path_complete_path=Path(glob_path_complete_path_inter)
    mod_folder_name = 'Mod-' + str(company_name)
    mod_full_dir = os.path.join(dir_litw_resized,mod_folder_name) 
    brand_count_row=1
    for filename_logo in glob_path_complete_path.glob('**/*.jpg'):
         with open(filename_logo) as imagefile:
            if brand_count_row > 200:
                return df_logos_pickle
            image_original = Image.open(filename_logo)
            dir_name,file_orig_name = os.path.split(filename_logo)
            get_file_data_shape_x, get_file_data_shape_y = image_original.size
            max_size_dimension = max(float(get_file_data_shape_x),float(get_file_data_shape_y))
            if max_size_dimension < size_threshold:
                continue 
            img_mod_name = company_name +'-AB-'+ str(index_image) +'.png'
            
            os.makedirs(mod_full_dir, exist_ok=True)
            path_to_image = os.path.join(mod_full_dir,img_mod_name)             
            
            company_brand_name = company_name         
           

            image_aspect=fix_aspect_ratio(image_original,expected_dimension)
            
            img_new = make_square(image_aspect)
            
            sharpen_image=sharpen_filter(img_new)
            im_med = ndimage.median_filter(sharpen_image, 3)
            norm_image=cv2.normalize(im_med,None,0,1, cv2.NORM_MINMAX)
            
            mean_values, std_values = cv2.meanStdDev(norm_image)
            mscn_values= calculate_MSCN_val(norm_image)
            mean_mean_val = np.mean(mean_values)
            mean_std_val = np.mean(std_values)
            mean_mscn_val =  np.mean(mscn_values)
            company_brand_name = company_name
            
           
           # mscn_val=calculate_MSCN_values(norm_image)

            row = pd.Series({'true_logo' :folder_logo_num,
                            'logo_img_name' :img_mod_name,
                             'original_image_name' :file_orig_name,
                             'company_brand' :company_brand_name,
                             'folder_path':mod_full_dir,
                            'mean_mean_val': mean_mean_val,
                            'mean_std_val': mean_std_val,
                            'mscn_val': mean_mscn_val,})
            
            df_logos_pickle = df_logos_pickle.append(row,ignore_index=True) 
            
            brand_count_row=brand_count_row+1
            file_name=os.path.join(mod_full_dir,img_mod_name)
            misc.imsave(file_name, im_med)
            index_image =index_image+1
            
  

    return df_logos_pickle

# %%
# Prepare the logos dataset datastructure
# Set threshold for the size of the logo images to avoid heavy distortion due to resize

def get_all_images():

    
    
    df_list=[]
    df_folder_Stat_list=[]
    folder_logo_num=0
    folders = ([name for name in sorted(os.listdir(dir_litw), key=str.casefold)]) # get all directories 
    for company_name in folders:
        expected_dimension=120
        size_threshold=17
        folder_path_global=dir_litw
        #verify_images_df(folder_path_global, company_name,dir_litw, size_threshold,folder_logo_num,expected_dimension)
        df_list.append(resize_images_df(folder_path_global, company_name,dir_litw_resized, expected_dimension,size_threshold,folder_logo_num))
        # print(df_list)
        #df_folder_Stat_list=df_folder_Stat_list.append([df_folder_Stat])
        
        tp_df = pd.concat(df_list, ignore_index=True)  
        #tp_df_stat=pd.concat(df_folder_Stat, ignore_index=True) 
        folder_logo_num=folder_logo_num+1
    return tp_df

# %%
tp_df_image_resized=get_all_images()

#tp_df_image_resized=
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
tp_df_image_resized.head()
# Out:
#   true_logo       logo_img_name            original_image_name company_brand  \
# 0         0    1fcköln-AB-1.png  coca-cola_img000028_44_18.jpg       1fcköln
# 1         1  24fitness-AB-1.png    Walmart_img000083_108_2.jpg     24fitness
# 2         2    7eleven-AB-1.png       shell_img000159_96_2.jpg       7eleven
# 3         2    7eleven-AB-2.png     target_img000210_100_6.jpg       7eleven
# 4         3         a1-AB-1.png      kraft_img000000_70_54.jpg            a1
#
#                                          folder_path  mean_mean_val  \
# 0  c:\Users\Sanyogita\Documents\Insight\projects\...       0.733385
# 1  c:\Users\Sanyogita\Documents\Insight\projects\...       0.322917
# 2  c:\Users\Sanyogita\Documents\Insight\projects\...       0.293177
# 3  c:\Users\Sanyogita\Documents\Insight\projects\...       0.292760
# 4  c:\Users\Sanyogita\Documents\Insight\projects\...       0.429323
#
#    mean_std_val    mscn_val
# 0      0.393305  113.016059
# 1      0.456953  125.239236
# 2      0.297608   79.330382
# 3      0.422124   21.213108
# 4      0.483033   48.451476

# %%
def get_folder_stats(df_logos_folder_label, df_folder_details,dir_path):
    
    
    df_logos_folder = pd.DataFrame(columns=['company_brand','folder_mean_val','folder_std_val','folder_mscn_val','folder_path']) 
   
    folders = ([name for name in sorted(os.listdir(dir_path), key=str.casefold)]) # get all directories 
    
    for company_name in folders:
        
        company_name=company_name[4:len(company_name)] # Remove Mod- from the name
        
        df_rows=df_folder_details.loc[df_folder_details['company_brand'] == company_name]
        
        mean_mean_val=df_rows["mean_mean_val"].mean() 
        mean_std_val=df_rows["mean_std_val"].mean()
        mean_mscn_val=df_rows["mscn_val"].mean() 
        row = pd.Series({'company_brand' :company_name,
                            'folder_mean_val': mean_mean_val,
                            'folder_std_val': mean_std_val,
                            'folder_mscn_val': mean_mscn_val,
                            'folder_path': df_rows["folder_path"]})
            
        df_logos_folder = df_logos_folder.append(row,ignore_index=True) 
    return df_logos_folder

# %%
df_logos_folder_label.head()
# Out:
#   true_logo   folder_name folder_img_count  \
# 0         1       1fcköln                1
# 1         2     24fitness                1
# 2         3       7eleven                2
# 3         4            a1               17
# 4         5  absolutvodka                1
#
#                                          folder_path
# 0  c:\Users\Sanyogita\Documents\Insight\projects\...
# 1  c:\Users\Sanyogita\Documents\Insight\projects\...
# 2  c:\Users\Sanyogita\Documents\Insight\projects\...
# 3  c:\Users\Sanyogita\Documents\Insight\projects\...
# 4  c:\Users\Sanyogita\Documents\Insight\projects\...

# %%
df_logos_folder=get_folder_stats(df_logos_folder_label, tp_df_image_resized,dir_litw_resized)

# %%
tp_df_image_resized.to_csv('folder_image_Details_7022019_v3.csv')
df_logos_folder_label.to_csv('folder_Stats_7022019_v3.csv')

# %%
# Load dataset of logos in a dataframe
def get_file_excluded_1(folder_path_global, company_name,dir_litw_resized, expected_dimension,size_threshold, folder_logo_num, threshold_mean,threshold_std,threshold_mscn):
    df_logos_pickle = pd.DataFrame(columns=['true_logo','logo_img_name','original_image_name','company_brand','mean_mean_val','mean_std_val','mscn_val','img_path'])
    
     # in each folder, find image file and resize-scale them without distortion
    index_image= 1;
    #print(glob_path_complete) 
    glob_path_complete_path_inter=os.path.join(folder_path_global,company_name)
    glob_path_complete_path=Path(glob_path_complete_path_inter)
    mod_folder_name = str(company_name)
    mod_full_dir = os.path.join(dir_litw_resized,mod_folder_name) 
    brand_count_row=1
    
    for filename_logo in glob_path_complete_path.glob('**/*.png'):
         with open(filename_logo) as imagefile:
            
           
            
            image_original = Image.open(filename_logo)
            dir_name,file_orig_name = os.path.split(filename_logo)
            get_file_data_shape_x, get_file_data_shape_y = image_original.size
            max_size_dimension = max(float(get_file_data_shape_x),float(get_file_data_shape_y))
            if max_size_dimension < size_threshold:
                continue 
            
            img_mod_name = company_name +'-AB-'+ str(index_image) +'.png'
            
                        
            
            company_brand_name = company_name         
           

            image_aspect=fix_aspect_ratio(image_original,expected_dimension)
            
            img_new = make_square(image_aspect)
            
            sharpen_image=sharpen_filter(img_new)
            im_med = ndimage.median_filter(sharpen_image, 3)
            norm_image=cv2.normalize(im_med,None,0,1, cv2.NORM_MINMAX)
            
            mean_values, std_values = cv2.meanStdDev(norm_image)
            mscn_values= calculate_MSCN_val(norm_image)
            mean_mean_val = np.mean(mean_values)
            mean_std_val = np.mean(std_values)
            mean_mscn_val =  np.mean(mscn_values)
            company_brand_name = company_name
            
            if mean_mean_val < threshold_mean or mean_std_val < threshold_std or abs(mean_mscn_val) < abs(threshold_mscn):
                continue
             
            
            os.makedirs(mod_full_dir, exist_ok=True)
            path_to_image = os.path.join(mod_full_dir,img_mod_name) 
            #mscn_val=calculate_MSCN_values(norm_image)
            file_name=os.path.join(mod_full_dir,img_mod_name)
            misc.imsave(file_name, im_med)
            
            row = pd.Series({'true_logo' :folder_logo_num,
                            'logo_img_name' :img_mod_name,
                             'original_image_name' :file_orig_name,
                             'company_brand': mod_folder_name,
                            'mean_mean_val': mean_mean_val,
                            'mean_std_val': mean_std_val,
                            'mscn_val': mean_mscn_val,
                            'img_path': file_name,})
            
            df_logos_pickle = df_logos_pickle.append(row,ignore_index=True) 
            
           
            
            index_image =index_image+1
            brand_count_row=brand_count_row+1
            #if brand_count_row > 10: # store 10 images
                #return df_logos_pickle
                        
   
    return df_logos_pickle

# %%
def test_data_exclusion_1(df_logos_folder,A,B,C,dir_litw_resized,dir_litw):
    
    
    
    df_list=[]
    df_folder_Stat_list=[]
    folder_logo_num=0
    mn=0
    folders = ([name for name in sorted(os.listdir(dir_litw), key=str.casefold)]) # get all directories 
    for company_name in folders:
        contents = os.listdir(os.path.join(dir_litw,company_name)) # get list of contents
        if len(contents) <= mn: # if greater than the limit, print folder and number of contents
            continue
       
           
           
        company_name=company_name[4:len(company_name)] # check company name with the PD company name to retrieve stats
        pd_company_stat_row = df_logos_folder.loc[df_logos_folder["company_brand"] == company_name]
        mean_threshold=A*((pd_company_stat_row["folder_mean_val"]).values[0])
        stdev_threshold=B*((pd_company_stat_row["folder_std_val"]).values[0])
        mscn_threshold=C*((pd_company_stat_row["folder_mscn_val"]).values[0]) #A=1,B=1,C=0.8 FOR UNSUPERVISED
       
        expected_dimension=120
        size_threshold=17
        folder_path_global=dir_litw
        company_name= "Mod-"+str(company_name)
        #verify_images_df(folder_path_global, company_name,dir_litw, size_threshold,folder_logo_num,expected_dimension)
        df_list.append(get_file_excluded_1(folder_path_global, company_name,dir_litw_resized, expected_dimension,size_threshold, folder_logo_num, mean_threshold,stdev_threshold,mscn_threshold))
        # print(df_list)
        #df_folder_Stat_list=df_folder_Stat_list.append([df_folder_Stat])
        tp_df = pd.concat(df_list, ignore_index=True)  
        #tp_df_stat=pd.concat(df_folder_Stat, ignore_index=True) 
        folder_logo_num=folder_logo_num+1
        #print(company_name,len(df_list))
   
    return tp_df

# %%
def Print_filtered_folder_details(storage_dir):
    
    folders = ([name for name in sorted(os.listdir(storage_dir), key=str.casefold)]) # get all directories 
    num_folders =1
    mn=120
    for company_name in folders:
        contents = os.listdir(os.path.join(storage_dir,company_name)) # get list of contents
        if len(contents) < mn:
            continue
        else:
            print(company_name,len(contents))

# %%
A=0.5
B=0.5
C=0.4

tp_df_excluded=test_data_exclusion_1(df_logos_folder,A,B,C, dir_litw_super_cleaned,dir_litw_resized)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
Print_filtered_folder_details(dir_litw_super_cleaned)
# Out:
# Mod-aldi 142
# Mod-audi-symbol 125
# Mod-bionade 166
# Mod-burgerking-symbol 154
# Mod-canon 166
# Mod-cat 145
# Mod-coca-cola 164
# Mod-colgate 159
# Mod-fedex 141
# Mod-gillette 153
# Mod-h&m 130
# Mod-heineken 166
# Mod-huawei-symbol 131
# Mod-intel 154
# Mod-kelloggs 156
# Mod-kraft 171
# Mod-nescafe 150
# Mod-pampers 155
# Mod-redbull 145
# Mod-redbull-symbol 141
# Mod-shell-symbol 137
# Mod-starbucks-symbol 148
# Mod-tmobile 132
# Mod-toyota 125
# Mod-vw 139

# %%
import pickle
tp_df_image_resized.to_pickle('image_logos_folder_path_7022019.pkl')
